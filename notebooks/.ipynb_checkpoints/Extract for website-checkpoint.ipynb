# %%
df.head()
# Out:
#    Rank     Time             Name Country Date of Birth Place     City  \
# 0     1  2:00:35    Kelvin Kiptum     KEN      02.12.99     1  Chicago
# 1     2  2:01:09   Eliud Kipchoge     KEN      05.11.84     1   Berlin
# 2     3  2:01:25    Kelvin Kiptum     KEN      02.12.99     1   London
# 3     4  2:01:39   Eliud Kipchoge     KEN      05.11.84     1   Berlin
# 4     5  2:01:41  Kenenisa Bekele     ETH      13.06.82     1   Berlin
#
#          Date Gender     Event
# 0  08.10.2023    Men  Marathon
# 1  25.09.2022    Men  Marathon
# 2  23.04.2023    Men  Marathon
# 3  16.09.2018    Men  Marathon
# 4  29.09.2019    Men  Marathon

# %%
df['Datetime'] = df['Time'].apply(pd.to_datetime, errors='coerce')
df['City'] = df['City'].replace('New York City', 'New York')

df['Date'] = pd.to_datetime(df['Date'], infer_datetime_format=True)
df['Year'] = df['Date'].dt.year

# %%
marathons_df = df.loc[
    (df['Event'] == 'Marathon')
]

# %%
unique_cities_sorted = marathons_df['City'].value_counts().sort_values(ascending=False)
major_cities = unique_cities_sorted[unique_cities_sorted > 50]
major_cities
# Out:
# London         649
# Berlin         452
# Tokyo          429
# Chicago        368
# Boston         359
# Paris          346
# Valencia       344
# Amsterdam      321
# Rotterdam      293
# New York       292
# Osaka          290
# Seoul          284
# Dubai          282
# Frankfurt      269
# Nagoya         238
# Hamburg        193
# Sevilla        176
# Fukuoka        174
# Otsu           169
# Praha          143
# Beijing        139
# Roma           129
# Eindhoven      122
# Toronto        121
# Wien           121
# Milano         121
# Barcelona      106
# Xiamen         101
# Shanghai        92
# Houston         88
# Daegu           88
# Ljubljana       70
# Los Angeles     70
# Enschede        62
# Lisboa          62
# Torino          61
# Kosice          56
# Ottawa          52
# Name: City, dtype: int64

# %%
marathons_df = marathons_df[marathons_df['City'].isin(major_cities.index)]

# %%
idx = marathons_df.groupby(['City', 'Gender'])['Datetime'].idxmin()
best_times = marathons_df.loc[idx][['Time', 'Name', 'Country', 'City', 'Gender', 'Date', 'Year']]
best_times
# Out:
#           Time                   Name Country       City Gender       Date  \
# 114    2:04:40  Reuben Kiprop Kipyego     KEN  Abu Dhabi    Men 2019-06-12
# 18386  2:20:41          Eunice Chumba     BRN  Abu Dhabi  Women 2022-12-17
# 20477  2:27:03           Zhou Chunxiu     CHN  Ad-Dawhah  Women 2006-09-12
# 364    2:05:47         Erick Kiptanui     KEN  Ampugnano    Men 2021-11-04
# 18339  2:20:08           Angela Tanui     KEN  Ampugnano  Women 2021-11-04
# ...        ...                    ...     ...        ...    ...        ...
# 18760  2:23:07         Lydia Cheromei     KEN   Yokohama  Women 2012-11-18
# 4549   2:10:14            Titus Tuwei     KEN  Zhengzhou    Men 2017-03-26
# 20172  2:26:34             Wang Jiali     CHN  Zhengzhou  Women 2008-03-30
# 674    2:06:38        Tadesse Abraham     SUI     Zürich    Men 2022-10-04
# 19104  2:24:14             Helen Tola     ETH     Zürich  Women 2023-04-23
#
#        Year
# 114    2019
# 18386  2022
# 20477  2006
# 364    2021
# 18339  2021
# ...     ...
# 18760  2012
# 4549   2017
# 20172  2008
# 674    2022
# 19104  2023
#
# [368 rows x 7 columns]

# %%
best_times['Date'] = best_times['Date'].dt.strftime('%Y-%m-%d')
best_times.to_json(
    '../public/best_times.json', 
    orient='records',
    indent=2
)

# %%
idx = marathons_df.groupby(['City', 'Gender'])['Date'].idxmax()
latest_times = marathons_df.loc[idx][['Time', 'Name', 'Country', 'City', 'Gender', 'Date', 'Year']]
latest_times
# Out:
#           Time              Name Country       City Gender       Date  Year
# 252    2:05:20  Timothy Kiplagat     KEN  Abu Dhabi    Men 2022-12-17  2022
# 18386  2:20:41     Eunice Chumba     BRN  Abu Dhabi  Women 2022-12-17  2022
# 20477  2:27:03      Zhou Chunxiu     CHN  Ad-Dawhah  Women 2006-09-12  2006
# 364    2:05:47    Erick Kiptanui     KEN  Ampugnano    Men 2021-11-04  2021
# 18339  2:20:08      Angela Tanui     KEN  Ampugnano  Women 2021-11-04  2021
# ...        ...               ...     ...        ...    ...        ...   ...
# 20411  2:26:57     Tomomi Tanaka     JPN   Yokohama  Women 2014-11-16  2014
# 4549   2:10:14       Titus Tuwei     KEN  Zhengzhou    Men 2017-03-26  2017
# 20874  2:27:39     Tigist Mamuye     ETH  Zhengzhou  Women 2017-03-26  2017
# 2905   2:09:12       Mark Kiptoo     KEN     Zürich    Men 2023-04-23  2023
# 19104  2:24:14        Helen Tola     ETH     Zürich  Women 2023-04-23  2023
#
# [368 rows x 7 columns]

# %%
latest_times['Date'] = latest_times['Date'].dt.strftime('%Y-%m-%d')
latest_times.to_json(
    '../public/latest_times.json', 
    orient='records',
    indent=2,
)
